# %% [markdown]
# ![alt text](image/python.png "")

# %% [markdown]
# # Step 1: Load the Pre-trained Model
# We will use MobileNetV3Large, a lightweight neural network trained on ImageNet.
# ![alt text](image/mobilenet-v3-block.png "")
# **The Deep Learning Model is provided by TensorFlow and Keras.**

# %%
from tensorflow.keras.applications import MobileNetV3Large # type: ignore

# Load pre-trained MobileNetV3Large model
model = MobileNetV3Large(weights='imagenet', input_shape=(224, 224, 3))

# %% [markdown]
# # Step 2: Define Function that grabs an Image from any GenICam compliant Camera
# This function just grabs one image and makes the transfer to 3rd party (numpy)
#
# ![alt text](image/numpy.png "")
#
# **CVB is used as acquisition SDK**

# %%
import cvb
import os

def capture_frame(stream):
    
    wait_result = stream.wait()
    composite: cvb.Image = wait_result[0]
    
    return cvb.to_array(composite)

# %% [markdown]
# # Step 3: Preprocess the Captured Image
# We resize the image to 384x384 pixels and normalize it for the EfficientNetV2S model.

# %%
from PIL import Image
import numpy as np
from tensorflow.keras.applications.mobilenet_v3 import preprocess_input # type: ignore

def preprocess_image(img_array):
    """Ensures image has 3 channels, resizes, and preprocesses for MobileNetV3Large."""
    if len(img_array.shape) == 2:  # Grayscale image
        img_array = np.stack([img_array] * 3, axis=-1)  # Convert to 3-channel RGB
    
    img = Image.fromarray(img_array)
    img = img.resize((224, 224), Image.LANCZOS) # type: ignore
    img_array = np.array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)
    return img_array, np.array(img).copy()

# %% [markdown]
# # Step 4: Make a Prediction Using MobileNetV2
# The preprocessed image is passed to the model, and we retrieve the top-3 predictions.

# %%
from tensorflow.keras.applications.mobilenet_v3 import decode_predictions # type: ignore

def predict_image(img_array):
    """Predicts the class of an image using MobileNet_v3."""
    predictions = model.predict(img_array,verbose=0);
    decoded = decode_predictions(predictions, top=3)[0]
    return decoded

# %% [markdown]
# # Step 5: Display Results
# The original captured image is displayed along with the model's predictions.

# %%
import matplotlib.pyplot as plt
from IPython.display import clear_output, display
import PIL

def showarray(display, a, fmt='jpeg'):
    clear_output(wait=True)
    display(PIL.Image.fromarray(a))
    
def display_results(display, image_array, predictions):
    """Displays the captured image along with the predictions."""
    showarray(display, image_array)
    print(f"Predictions:\n" + "\n".join([f"{label}: {score:.2f}" for (_, label, score) in predictions]))

# %% [markdown]
# # Step 6: Run the Pipeline
# Now we capture an image, process it, and display the results.

# %%
import cvb

display_handle=display(None, display_id=True)
# get the absolute path to the curre
"""Captures a single frame from the CVB device."""
devices = cvb.DeviceFactory.discover_from_root(cvb.DiscoverFlags.IgnoreVins|cvb.DiscoverFlags.IncludeMockTL, time_span=30)
if not devices:
    raise RuntimeError("No suitable device found.")

device_token = next(iter(dev.access_token for dev in devices if "DFK" in dev.access_token), None)
if not device_token:
    raise RuntimeError("No Mock device found.")

with cvb.DeviceFactory.open(device_token, cvb.AcquisitionStack.GenTL) as device:
    device: cvb.GenICamDevice = device
    # prepare_device(device)
    stream = device.stream(cvb.ImageStream)
    stream.start()
    print("device started")
    while True:
        try:
            captured_image = capture_frame(stream)
            processed_image, showimage = preprocess_image(captured_image)
            predictions = predict_image(processed_image)
            # Display results
            if not showimage:
                continue
            display_results(display, showimage, predictions)
        except KeyboardInterupt:
            print("Exiting...")
            break
        except Exception as e:
            print("error: "+ str (e))
            continue
    stream.stop()
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>
# Predictions:
# water_bottle: 0.29
# perfume: 0.15
# gas_pump: 0.12
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 24
#      23 processed_image, showimage = preprocess_image(captured_image)
# ---> 24 predictions = predict_image(processed_image)
#      25 # Display results
#
# Cell In[4], line 5, in predict_image(img_array)
#       4 """Predicts the class of an image using MobileNet_v3."""
# ----> 5 predictions = model.predict(img_array,verbose=0);
#       6 decoded = decode_predictions(predictions, top=3)[0]
#
# File c:\Users\s.woelzmueller\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#
# File c:\Users\s.woelzmueller\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\keras\src\engine\training.py:2550, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2549 batch_outputs = None
# -> 2550 for _, iterator in data_handler.enumerate_epochs():  # Single epoch.
#    2551     with data_handler.catch_stop_iteration():
#
# File c:\Users\s.woelzmueller\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\keras\src\engine\data_adapter.py:1331, in DataHandler.enumerate_epochs(self)
#    1330 with self._truncate_execution_to_epoch():
# -> 1331     data_iterator = iter(self._dataset)
#    1332     for epoch in range(self._initial_epoch, self._epochs):
#
# File c:\Users\s.woelzmueller\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:506, in DatasetV2.__iter__(self)
#     505   with ops.colocate_with(self._variant_tensor):
# --> 506     return iterator_ops.OwnedIterator(self)
#     507 else:
#
# File c:\Users\s.woelzmueller\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:710, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     707     raise ValueError(
#     708         "When `dataset` is provided, `element_spec` and `components` must "
#     709         "not be specified.")
# --> 710   self._create_iterator(dataset)
#     712 self._get_next_call_count = 0
#
# File c:\Users\s.woelzmueller\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:749, in OwnedIterator._create_iterator(self, dataset)
#     748   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 749 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File c:\Users\s.woelzmueller\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3451, in make_iterator(dataset, iterator, name)
#    3450 try:
# -> 3451   _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3452     _ctx, "MakeIterator", name, dataset, iterator)
#    3453   return _result
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 14
#      11 if not device_token:
#      12     raise RuntimeError("No Mock device found.")
# ---> 14 with cvb.DeviceFactory.open(device_token, cvb.AcquisitionStack.GenTL) as device:
#      15     device: cvb.GenICamDevice = device
#      16     # prepare_device(device)
#
# Cell In[6], line 27
#      25     # Display results
#      26     display_results(display, showimage, predictions)
# ---> 27 except KeyboardInterupt:
#      28     print("Exiting...")
#      29     break
#
# NameError: name 'KeyboardInterupt' is not defined
